// %%
lib [OTPReal] : {
    rout eavesdrop(m : {0,1}) : {
        k <- {0,1};
        c := k xor m;
        return c;
    }
}
lib [OTPRand] : {
    rout eavesdrop(m : {0,1}) : {
        c <- {0,1};
        return c;
    }
}

"In chapter 2, we proved".
show(lib[OTPReal] == lib[OTPRand]).
"With this fact, and from the definition of interchangability, we know that for all calling programs $\A$".
show pro[A] <> lib[OTPReal].
"reduces to the same program as"
show pro[A] <> lib[OTPRand].
"".
