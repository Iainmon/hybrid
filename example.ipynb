# %%
lib [WeekFour] : {
    rout bdp(q,N) : {
        1111111;
        if q * 1 then : {
            return 1;
        }
        p := 1 - (q/N);
        return p * bdp(q-1,N);
    }
    rout BirthdayProb(q,N) : {

        return 1 - bdp(q,N);
    }
}

show lib[WeekFour] == lib[WeekFour].
"There's a bug so things have to end with text".

# %%
lib[Kassia] : {
    rout walk(from,to) : {
        if obstacle then : {
            GoAround(obstacle);
        }
        return destination(to);
    }
}
show lib[Kassia].
".".

# %%
pro [A] : {
    MyProgram();
}

lib [Example] : {
    rout MyProgram() : {
        x <- {0,1};
        if x is 1 then : {
            return 1;
        }
        return 0;
    }
}
pro [AE] : {
    x <- {0,1};
    if x is 1 then : {
        return 1;
    }
    return 0;
}
pro [AER] : {
    x <- {0,1};
    return z;
}
show pro[A] <> lib[Example] == pro[AE] == pro[AER].
".".
